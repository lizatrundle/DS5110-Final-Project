# %% [markdown]
# # Part 3: Train a DQN on a Ray cluster

# %%
# In this part, you will connect to your Ray cluster.
# TODO: change the IP address of your head node.

import ray
ip_address = "172.31.22.134"
ray.init(address=f"ray://{ip_address}:10001")
# Out:
# ClientContext(dashboard_url='127.0.0.1:8265', python_version='3.10.12', ray_version='2.10.0', ray_commit='09abba26b5bf2707639bb637c208d062a47b46f6', _num_clients=1, _context_to_restore=<ray.util.client._ClientContext object at 0x7e7d0d439e40>, protocol_version=None)

# %%
# Print the status of the Ray cluster.
print('''This cluster consists of
    {} nodes in total
    {} CPU resources in total
    {} Memory resources in total
    {} Object store memory resources in total
    '''.format(len(ray.nodes()), ray.cluster_resources()['CPU'], 
           ray.cluster_resources()['memory'] / (1024*1024*1024), 
           ray.cluster_resources()['object_store_memory'] / (1024*1024*1024)))
# Out:
# This cluster consists of
#     5 nodes in total
#     10.0 CPU resources in total
#     25.123119356110692 Memory resources in total
#     11.077681730501354 Object store memory resources in total

# %%
# %%time

'''
(Optional testing code) 
Test your Ray cluster, see the outputs to check if all nodes are ready to work
the output should be like "123 tasks on 1.2.3.4 with Gym version 0.21.0".
By default, you have 5 nodes, one is the head node, the others are workers (actors).
'''
import socket
import time
from collections import Counter

@ray.remote
def f():
    import torch
    import gym
    time.sleep(0.001)
    return socket.gethostbyname(socket.gethostname()),gym.__version__

object_ids = [f.remote() for _ in range(1000)]
results = ray.get(object_ids)

print('Tasks executed')

stats = {}

for ip_address, version in results:
    if ip_address in stats:
        stats[ip_address] = (stats[ip_address][0] + 1, version)
    else:
        stats[ip_address] = (1, version)

for ip_address, (num_tasks, version) in stats.items():
    print('    {} tasks on {} with Gym version {}'.format(num_tasks, ip_address, version))
# Out:
# Tasks executed
#     429 tasks on 172.31.20.220 with Gym version 0.21.0
#     283 tasks on 172.31.32.117 with Gym version 0.21.0
#     137 tasks on 172.31.35.194 with Gym version 0.21.0
#     149 tasks on 172.31.33.44 with Gym version 0.21.0
#     2 tasks on 172.31.22.134 with Gym version 0.21.0
# CPU times: user 485 ms, sys: 114 ms, total: 599 ms
# Wall time: 4.63 s

# %%
import random
import numpy as np
import torch
import ray
import gym
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from collections import deque, namedtuple
import time
import socket

# %%
'''
DO NOT MODIFY THIS CELL.
We use DQN as our RL training algorithm.
See https://huggingface.co/learn/deep-rl-course/en/unit3/deep-q-algorithm to get more infomation about DQN.
'''
class QNetwork(nn.Module):
    def __init__(self, state_size, action_size, seed, fc1_unit=64,
                 fc2_unit=64):
        """
        Initialize parameters and build model.
        Params
        =======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fc1_unit (int): Number of nodes in first hidden layer
            fc2_unit (int): Number of nodes in second hidden layer
        """
        super(QNetwork, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, fc1_unit)
        self.fc2 = nn.Linear(fc1_unit, fc2_unit)
        self.fc3 = nn.Linear(fc2_unit, action_size)

    def forward(self, x):
        """
        Build a network that maps state -> action values.
        """
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

# %%
'''
DO NOT MODIFY THIS CELL.
The ReplayBuffer is an essential component in Deep Q-Networks (DQN)
It stores the Agent's experiences at each time step, comprised of the state, action, reward, next state, and done flag, in a memory buffer.
This allows for the experiences to be randomly sampled later to train the neural network.
'''
class ReplayBuffer:
    """Fixed-size buffer to store experience tuples."""

    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayBuffer object.
        Params
        ======
            action_size (int): dimension of each action
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
            seed (int): random seed
        """
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        random.seed(seed)

    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)

    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float()
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long()
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float()
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float()
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float()

        return states, actions, rewards, next_states, dones

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %%
'''
DO NOT MODIFTY THIS CELL.
The Learner is interacting with the environment to learn an optimal policy for decision-making.
The logic is the same as the Agent in the DQN algorithm, with only a different name here.
'''
class Learner:
    """Interacts with and learns from the environment."""

    def __init__(self, state_size, action_size, seed):
        """Initialize a Learner object.

        Params
        ======
            state_size (int): dimension of each state
            action_size (int): dimension of each action
            seed (int): random seed
        """
        random.seed(seed)
        self.state_size = state_size
        self.action_size = action_size

        # Q-Network
        self.qnetwork_local = QNetwork(state_size, action_size, seed)
        self.qnetwork_target = QNetwork(state_size, action_size, seed)
        print(learning_rate)
        self.optimizer = optim.Adam(self.qnetwork_local.parameters(), lr=learning_rate)

        # Replay memory
        self.memory = ReplayBuffer(action_size, buffer_size, batch_size, seed)

        # Initialize time step (for updating every UPDATE_EVERY steps)
        self.t_step = 0

    def step(self, state, action, reward, next_state, done):
        # Save experience in replay memory
        self.memory.add(state, action, reward, next_state, done)

        # Learn every UPDATE_EVERY time steps.
        self.t_step = (self.t_step + 1) % update_every
        if self.t_step == 0:
            # If enough samples are available in memory, get random subset and learn
            if len(self.memory) > batch_size:
                experiences = self.memory.sample()
                self.learn(experiences, gamma)

    def act(self, state, eps=0.):
        """Returns actions for given state as per current policy.

        Params
        ======
            state (array_like): current state
            eps (float): epsilon, for epsilon-greedy action selection
        """
        state = torch.from_numpy(state).float().unsqueeze(0)
        self.qnetwork_local.eval()
        with torch.no_grad():
            action_values = self.qnetwork_local(state)
            # print action_values
        self.qnetwork_local.train()

        # Epsilon-greedy action selection
        if random.random() > eps:
            return np.argmax(action_values.cpu().data.numpy())
        else:
            action = random.choice(np.arange(self.action_size))
            return action

    def learn(self, experiences, gamma):
        """Update value parameters using given batch of experience tuples.
        Params
        ======
            experiences (Tuple[torch.Tensor]): tuple of (s, a, r, s', done) tuples
            gamma (float): discount factor
        """
        states, actions, rewards, next_states, dones = experiences

        # Get max predicted Q values (for next states) from target model
        q_targets_next = self.qnetwork_target(next_states).detach().max(1)[0].unsqueeze(1)
        # Compute Q targets for current states
        q_targets = rewards + (gamma * q_targets_next * (1 - dones))

        # Get expected Q values from local model
        q_expected = self.qnetwork_local(states).gather(1, actions)

        # Compute loss
        loss = F.mse_loss(q_expected, q_targets)
        # Minimize the loss
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # update target network
        self.soft_update(self.qnetwork_local, self.qnetwork_target, tau)

    def soft_update(self, local_model, target_model, tau):
        """Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target
        Params
        ======
            local_model (PyTorch model): weights will be copied from
            target_model (PyTorch model): weights will be copied to
            tau (float): interpolation parameter
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau * local_param.data + (1.0 - tau) * target_param.data)

# %%
def get_one_hot_encoding(state, next_state):
    state_encoding = np.array([0 for _ in range(500)])
    state_encoding[state] = 1
    next_state_encoding = np.array([0 for _ in range(500)])
    next_state_encoding[next_state] = 1
    return state_encoding, next_state_encoding

# %%
'''
This class implements a global network (i.e., a parameter server) in a distributed training setup.
It holds a global model that aggregates updates from multiple Agent actors to collectively learn a policy.
GlobalNet will also periodically test the learned policy in a dedicated test environment.
'''

"""
TODO: Task 0
"""
# Task 0 TODO: add Ray actor decorator here
# Hint: You need to specify the number of CPUs for this actor

"""
End of Task 0
"""
# By adding a ray decorator here, we are saying this class will be an actor with 2 cpu's each
@ray.remote(num_cpus=2)
class GlobalNet:
    def __init__(self, state_size, action_size, seed, fc1_unit=64, fc2_unit=64):
        random.seed(seed)
        self.local_model = QNetwork(state_size, action_size, seed, fc1_unit, fc2_unit)
        self.test_env = gym.make('Taxi-v3')
        #self.seed = seed
        self.test_env.seed(TEST_SEED)
        print(f"Initializing an Global Network on worker with IP: {self.get_worker_ip()}")

    def get_worker_ip(self):
        """Get the current worker's IP address."""
        hostname = socket.gethostname()
        ip_address = socket.gethostbyname(hostname)
        return ip_address

    def average_weights(self, actors):
        """
        Collects weights from all given actors and averages them to update the global model.

        Params:
            actors: list of actor handlers from which to collect weights
        """
        weights_futures = [actor.get_weights.remote() for actor in actors]
        local_weights_list = ray.get(weights_futures)
        local_state_dict = self.local_model.state_dict()

        # Initialize average weights
        average_local_weights = {k: torch.zeros_like(v) for k, v in local_state_dict.items()}
        # Sum all the weights
        for local_state in local_weights_list:
            for k, v in local_state.items():
                average_local_weights[k] += v
        # Average the weights
        for k in average_local_weights.keys():
            average_local_weights[k] = average_local_weights[k] / len(local_weights_list)

        #print(average_local_weights)
        self.local_model.load_state_dict(average_local_weights)

    def get_weights(self):
        """
        Returns the weights of the local model in the global network.
        """
        return self.local_model.state_dict()

    def play_game(self, max_timesteps=200, num_games=10):
        total_reward_sum = 0
        for _ in range(num_games):
            state = self.test_env.reset()
            if not isinstance(state, int):
                state = state[0]
            state, _ = get_one_hot_encoding(state, 0)
            total_reward = 0
            for t in range(max_timesteps):
                state_tensor = torch.from_numpy(state).float().unsqueeze(0)
                with torch.no_grad():
                    action_values = self.local_model(state_tensor)
                action = torch.argmax(action_values).item()

                next_state, reward, done, _ = self.test_env.step(action)[:4]
                _, next_state = get_one_hot_encoding(0, next_state)
                total_reward += reward
                state = next_state
                if done:
                    break
            total_reward_sum += total_reward

        average_reward = total_reward_sum / num_games
        return average_reward

# %%
'''
    This is a distributed Agent class for parallel training in reinforcement learning environments using Ray.
    Each Agent has its own environment and own learner for training.
    Each Agent instance runs in different nodes and is responsible for collecting experiences
    by interacting with its own environment and synchronizing with the global network.
'''

"""
TODO: Task 0
"""
# Task 0 TODO: add Ray actor decorator here
# Hint: You need to specify the number of CPUs for this actor

# TODO: Your code here...

"""
End of Task 0
"""
# By adding a ray decorator here, we are saying this class will be an actor with 2 cpu's each
@ray.remote(num_cpus=2)
class Agent:
    def __init__(self, state_size, action_size, seed):
        """
        Initialize an Agent object.
        Params
        ======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
        """
        random.seed(seed)
        self.learner = Learner(state_size, action_size, seed)

        # set game environment for training
        self.env = gym.make("Taxi-v3")
        self.env.seed(seed)
        self.seed = seed
        # self.env.seed(seed)

        self.max_t = max_time_steps
        self.eps_end = 0.01
        self.eps_decay = 0.995
        self.eps = 1.0
        print(f"Initializing an Actor on worker with IP: {self.get_worker_ip()}")

    def get_worker_ip(self):
        """Get the current worker's IP address."""
        hostname = socket.gethostname()
        ip_address = socket.gethostbyname(hostname)
        return ip_address

    def synchronize_with_global(self, global_net):
        """
        Synchronize the local model weights with the global model by fetching the global model's weights.
        Params:
            global_net: The handler for the GlobalNet actor.
        """
        global_weights = ray.get(global_net.get_weights.remote())
        self.learner.qnetwork_local.load_state_dict(global_weights)

    def train(self, num_episodes):
        """
        Train the learner's local model in the given environment.
        Params
        ======
            num_episodes (int): Number of episodes to train
        """
        for episode in range(num_episodes):
            state = self.env.reset()
            if not isinstance(state, int):
                state = state[0]
            state, _ = get_one_hot_encoding(state, 0)
            score = 0
            for t in range(self.max_t):
                action = self.learner.act(state, self.eps)
                #print(action)
                next_state, reward, done, _ = self.env.step(action)[:4]
                _, next_state = get_one_hot_encoding(0, next_state)
                self.learner.step(state, action, reward, next_state, done)
                state = next_state
                score += reward
                if done:
                    break
            self.eps = max(self.eps_end, self.eps_decay * self.eps)  # decrease epsilon

    def get_weights(self):
        """
        Returns the weights of the learner's local models.
        """
        return self.learner.qnetwork_local.state_dict()

# %%
'''
The driver code to run the distributed training on your Ray cluster. 
'''
import json
from json.decoder import JSONDecodeError
import os

# set random seed
SEED= 0
TEST_SEED = 42
random.seed(SEED)
# env config
state_size = 500
action_size = 6

"""
TODO: Task 6
"""
# hyperparameters you could tune
# Task 6 TODO: try different values of the following three hyperparameters once you have finished the other tasks.
# Default settings: batch_size = 64, num_epochs_actor_train = 1, num_agents = 4 
batch_size = 64  # the minibatch size
num_epochs_actor_train = 1  # how many epochs an Agent actor trains before synchronize with GlobalNet
num_agents = 4  # how many Agent actors to train in parallel
"""
End of Task 6
"""

# hyperprameters you don't need to tune
buffer_size = int(1e5)  # replay buffer size
gamma = 0.99  # discount factor
tau = 1e-3  # for soft update of target parameters
learning_rate = 5e-4  # learning rate
update_every = 4  # how often to update the network
max_time_steps = 1000  # max time steps in an episode for train
num_episodes = 1000  # how many episodes for training

# TODO: Your code here...
# Here I initialize the globalNet actor by calling the GlobalNet class with the ray.remote function
num_agents = 9
num_epochs_actor_train = 10
num_episodes = 2000

# Added hyperparameters
consecutive_cutoff = 5
consecutive_count = 0
cutoff_score = 9.7

hyperparameters = {
    "num_agents": 4,
    "num_epochs_actor_train": 10,
    "batch_size": 64,
    "gamma": 0.9,
    "tau": tau,
    "learning_rate": 1e-3,
    # 5e-5
    # 5e-3
    "update_every": update_every,
    "max_time_steps": max_time_steps,
    "num_episodes": 2000,
    "cutoff_score": cutoff_score,
    "consecutive_cutoff": consecutive_cutoff,
    "consecutive_count": consecutive_count
}

if "num_agents" in hyperparameters.keys():
    num_agents = hyperparameters["num_agents"]
if "num_epochs_actor_train" in hyperparameters.keys():
    num_epochs_actor_train = hyperparameters["num_epochs_actor_train"]
if "batch_size" in hyperparameters.keys():
    batch_size = hyperparameters["batch_size"]
if "gamma" in hyperparameters.keys():
    gamma = hyperparameters["gamma"]
if "tau" in hyperparameters.keys():
    tau = hyperparameters["tau"]
if "learning_rate" in hyperparameters.keys():
    learning_rate = hyperparameters["learning_rate"]
if "update_every" in hyperparameters.keys():
    update_every = hyperparameters["update_every"]
if "max_time_steps" in hyperparameters.keys():
    max_time_steps = hyperparameters["max_time_steps"]
if "num_episodes" in hyperparameters.keys():
    num_episodes = hyperparameters["num_episodes"]
if "cutoff_score" in hyperparameters.keys():
    cutoff_score = hyperparameters["cutoff_score"]
if "consecutive_cutoff" in hyperparameters.keys():
    consecutive_cutoff = hyperparameters["consecutive_cutoff"]
if "consecutive_count" in hyperparameters.keys():
    consecutive_count = hyperparameters["consecutive_count"]

"""
TODO: Task 1
"""
# Task 1.1 TODO: Initialize a GlobalNet actor and all N Agent actors where N = num_agents
# IMPORTANT: Each agent should take a different random seed so that each covers different random behaviors

globalNet_actor = GlobalNet.remote(state_size, action_size, SEED)

# Here I initialize N agent actors by calling the Agent class with the ray.remote function
# By including the for loop, it will create N Agent actors and append those actors to a list for future calls
# In order to have different seeds for each Agent, I increment the seed by 1 for each agent to ensure the agent covers
# different random behaviors
agent_actors = [Agent.remote(state_size, action_size, SEED + agent_id + 1) for agent_id in range(num_agents)]

time.sleep(1) # This line serves as a barrier. Do not modify this line.


# Task 1.2 TODO: Synchronize GlobalNet's model weights to all Agents at the very beginning

# TODO: Your code here...
# In this code, I loop through all the Agent actors created and synchronize their weights with the GlobalNet actor's weight
# I call get to insert a barrier and block the code to ensure the code works
syn = [agent.synchronize_with_global.remote(globalNet_actor) for agent in agent_actors]
ray.get(syn)

"""
End of Task 1
"""


# Initialize timers
times_update = []
times_sync = []
times_train = []
total_start_time = time.time()

game_score_times = []
average_game_reward = 0
consecutive_counter = 0

for episode in range(num_episodes):
    """
    TODO: Task 2 to Task 5
    """

    # Task 2 TODO: Train all agents in parallel
    # Hint: Insert a barrier by calling ray.get(X_future)
    start_time = time.time()

    # TODO: Your code here... 
    # Here I call the train method on each Agent actor (from my agent list) to get them to train
    # I call get to insert a barrier and block the code to ensure the code works
    ray.get([agent.train.remote(num_epochs_actor_train) for agent in agent_actors])
    
    end_time = time.time()
    times_train.append(end_time - start_time)

    #############################
    start_time = time.time()

    # Here I call the average_weights method on the GlobalNet actor to update its weights based upon all the Agent actors'
    # weights. 
    # I call get to insert a barrier and block the code to ensure the code works
    ray.get(globalNet_actor.average_weights.remote(agent_actors))
    
    end_time = time.time()
    times_update.append(end_time - start_time)

    #############################
    start_time = time.time()

    # TODO: Your code here...
    # Here I call the synchronize_with_global method on each Agent actor to update their weights based upon the GlobalNet actor's
    # weight. 
    # I call get to insert a barrier and block the code to ensure the code works
    ray.get([agent.synchronize_with_global.remote(globalNet_actor) for agent in agent_actors])
    
    end_time = time.time()
    times_sync.append(end_time - start_time)
    print(f'Episode {episode} finished.')

    # Task 5.1 TODO: Test the global model in GlobalNet and print the score here
    
    # TODO: Your code here...
    # Here, I make the GlobalNet actor call the play_game method after 10 episodes in order to get the average_game_reward
    # I call get to insert a barrier and block the code to ensure the code works
    # The episode and average score will be printed

    if episode % 10 == 0:    
        average_game_reward = ray.get(globalNet_actor.play_game.remote())
        if average_game_reward >= consecutive_cutoff:
            consecutive_counter += 1
        else:
            consecutive_counter = 0
        game_score_times.append((time.time()-total_start_time, episode, average_game_reward))
        print(f'Episode {episode}\tAverage Score: {average_game_reward:.2f}')
        
    # Task 5.2 and 5.3 TODO: Set the termination condition and save the GlobalNet weights as a checkpoint file
    # Hint: Call torch.save(your_model_weights, './model_checkpoint.pth') to save a model checkpoint
    
    # TODO: Your code here
    # In this code, I check to see if the average_game_reward if greater than or equal to 100 or the episode hits 1000
    # This is the termination condition to see if the training is completed (ie. the game was won/learned)
    # I call torch.save in order to create a model checkpoint to see a visualization of the game later
    # Lastly, I print how many episodes the game was solved in and then break out of the for loop
    if (average_game_reward >= cutoff_score and consecutive_counter >= consecutive_count) or episode >= num_episodes:
        
        print(f'Environment solved in {episode} episodes!')

        # Store data as JSON
        filename = 'taxi_data.json'
        
        data = []
        if os.path.exists(filename):
            with open(filename, 'r') as f:
                data = json.load(f)
        
        with open(filename, 'w+') as f:
            data.append({"parameters": {
                            "num_agents": num_agents,
                            "num_epochs_actor_train": num_epochs_actor_train,
                            "batch_size": batch_size,
                            "gamma": gamma,
                            "tau": tau,
                            "learning_rate": learning_rate,
                            "update_every": update_every,
                            "max_time_steps": max_time_steps,
                            "num_episodes": num_episodes,
                            "cutoff_score": cutoff_score,
                            "consecutive_cutoff": consecutive_cutoff,
                            "consecutive_count": consecutive_count
                        },
                "training": game_score_times})
            json.dump(data, f)
            torch.save(ray.get(globalNet_actor.get_weights.remote()), f'./tax_model_checkpoint_{len(data)}.pth')
        
        break

    """
    End of Task 2 to Task 5
    """


total_end_time = time.time()

print(f"Total duration: {total_end_time - total_start_time:.2f} seconds")
print(f"Average time for training: {np.mean(times_train):.2f} seconds")
print(f"Average time for updating: {np.mean(times_update):.2f} seconds")
print(f"Average time for synchronizing: {np.mean(times_sync):.2f} seconds")
# Out:
# Episode 0 finished.
# Episode 0	Average Score: -200.00
# Episode 1 finished.
# Episode 2 finished.
# Episode 3 finished.
# Episode 4 finished.
# Episode 5 finished.
# Episode 6 finished.
# Episode 7 finished.
# Episode 8 finished.
# Episode 9 finished.
# Episode 10 finished.
# Episode 10	Average Score: -200.00
# Episode 11 finished.
# Episode 12 finished.
# Episode 13 finished.
# Episode 14 finished.
# Episode 15 finished.
# Episode 16 finished.
# Episode 17 finished.
# Episode 18 finished.
# Episode 19 finished.
# Episode 20 finished.
# Episode 20	Average Score: -200.00
# Episode 21 finished.
# Episode 22 finished.
# Episode 23 finished.
# Episode 24 finished.
# Episode 25 finished.
# Episode 26 finished.
# Episode 27 finished.
# Episode 28 finished.
# Episode 29 finished.
# Episode 30 finished.
# Episode 30	Average Score: -137.10
# Episode 31 finished.
# Episode 32 finished.
# Episode 33 finished.
# Episode 34 finished.
# Episode 35 finished.
# Episode 36 finished.
# Episode 37 finished.
# Episode 38 finished.
# Episode 39 finished.
# Episode 40 finished.
# Episode 40	Average Score: -74.60
# Episode 41 finished.
# Episode 42 finished.
# Episode 43 finished.
# Episode 44 finished.
# Episode 45 finished.
# Episode 46 finished.
# Episode 47 finished.
# Episode 48 finished.
# Episode 49 finished.
# Episode 50 finished.
# Episode 50	Average Score: -54.40
# Episode 51 finished.
# Episode 52 finished.
# Episode 53 finished.
# Episode 54 finished.
# Episode 55 finished.
# Episode 56 finished.
# Episode 57 finished.
# Episode 58 finished.
# Episode 59 finished.
# Episode 60 finished.
# Episode 60	Average Score: -12.90
# Episode 61 finished.
# Episode 62 finished.
# Episode 63 finished.
# Episode 64 finished.
# Episode 65 finished.
# Episode 66 finished.
# Episode 67 finished.
# Episode 68 finished.
# Episode 69 finished.
# Episode 70 finished.
# Episode 70	Average Score: -12.70
# Episode 71 finished.
# Episode 72 finished.
# Episode 73 finished.
# Episode 74 finished.
# Episode 75 finished.
# Episode 76 finished.
# Episode 77 finished.
# Episode 78 finished.
# Episode 79 finished.
# Episode 80 finished.
# Episode 80	Average Score: -13.90
# Episode 81 finished.
# Episode 82 finished.
# Episode 83 finished.
# Episode 84 finished.
# Episode 85 finished.
# Episode 86 finished.
# Episode 87 finished.
# Episode 88 finished.
# Episode 89 finished.
# Episode 90 finished.
# Episode 90	Average Score: -54.30
# Episode 91 finished.
# Episode 92 finished.
# Episode 93 finished.
# Episode 94 finished.
# Episode 95 finished.
# Episode 96 finished.
# Episode 97 finished.
# Episode 98 finished.
# Episode 99 finished.
# Episode 100 finished.
# Episode 100	Average Score: -12.50
# Episode 101 finished.
# Episode 102 finished.
# Episode 103 finished.
# Episode 104 finished.
# Episode 105 finished.
# Episode 106 finished.
# Episode 107 finished.
# Episode 108 finished.
# Episode 109 finished.
# Episode 110 finished.
# Episode 110	Average Score: 7.00
# Episode 111 finished.
# Episode 112 finished.
# Episode 113 finished.
# Episode 114 finished.
# Episode 115 finished.
# Episode 116 finished.
# Episode 117 finished.
# Episode 118 finished.
# Episode 119 finished.
# Episode 120 finished.
# Episode 120	Average Score: 8.60
# Episode 121 finished.
# Episode 122 finished.
# Episode 123 finished.
# Episode 124 finished.
# Episode 125 finished.
# Episode 126 finished.
# Episode 127 finished.
# Episode 128 finished.
# Episode 129 finished.
# Episode 130 finished.
# Episode 130	Average Score: -11.30
# Episode 131 finished.
# Episode 132 finished.
# Episode 133 finished.
# Episode 134 finished.
# Episode 135 finished.
# Episode 136 finished.
# Episode 137 finished.
# Episode 138 finished.
# Episode 139 finished.
# Episode 140 finished.
# Episode 140	Average Score: -12.40
# Episode 141 finished.
# Episode 142 finished.
# Episode 143 finished.
# Episode 144 finished.
# Episode 145 finished.
# Episode 146 finished.
# Episode 147 finished.
# Episode 148 finished.
# Episode 149 finished.
# Episode 150 finished.
# Episode 150	Average Score: 7.90
# Episode 151 finished.
# Episode 152 finished.
# Episode 153 finished.
# Episode 154 finished.
# Episode 155 finished.
# Episode 156 finished.
# Episode 157 finished.
# Episode 158 finished.
# Episode 159 finished.
# Episode 160 finished.
# Episode 160	Average Score: 7.40
# Episode 161 finished.
# Episode 162 finished.
# Episode 163 finished.
# Episode 164 finished.
# Episode 165 finished.
# Episode 166 finished.
# Episode 167 finished.
# Episode 168 finished.
# Episode 169 finished.
# Episode 170 finished.
# Episode 170	Average Score: 7.70
# Episode 171 finished.
# Episode 172 finished.
# Episode 173 finished.
# Episode 174 finished.
# Episode 175 finished.
# Episode 176 finished.
# Episode 177 finished.
# Episode 178 finished.
# Episode 179 finished.
# Episode 180 finished.
# Episode 180	Average Score: 8.00
# Episode 181 finished.
# Episode 182 finished.
# Episode 183 finished.
# Episode 184 finished.
# Episode 185 finished.
# Episode 186 finished.
# Episode 187 finished.
# Episode 188 finished.
# Episode 189 finished.
# Episode 190 finished.
# Episode 190	Average Score: 8.50
# Episode 191 finished.
# Episode 192 finished.
# Episode 193 finished.
# Episode 194 finished.
# Episode 195 finished.
# Episode 196 finished.
# Episode 197 finished.
# Episode 198 finished.
# Episode 199 finished.
# Episode 200 finished.
# Episode 200	Average Score: 7.30
# Episode 201 finished.
# Episode 202 finished.
# Episode 203 finished.
# Episode 204 finished.
# Episode 205 finished.
# Episode 206 finished.
# Episode 207 finished.
# Episode 208 finished.
# Episode 209 finished.
# Episode 210 finished.
# Episode 210	Average Score: 7.90
# Episode 211 finished.
# Episode 212 finished.
# Episode 213 finished.
# Episode 214 finished.
# Episode 215 finished.
# Episode 216 finished.
# Episode 217 finished.
# Episode 218 finished.
# Episode 219 finished.
# Episode 220 finished.
# Episode 220	Average Score: 7.60
# Episode 221 finished.
# Episode 222 finished.
# Episode 223 finished.
# Episode 224 finished.
# Episode 225 finished.
# Episode 226 finished.
# Episode 227 finished.
# Episode 228 finished.
# Episode 229 finished.
# Episode 230 finished.
# Episode 230	Average Score: 8.10
# Episode 231 finished.
# Episode 232 finished.
# Episode 233 finished.
# Episode 234 finished.
# Episode 235 finished.
# Episode 236 finished.
# Episode 237 finished.
# Episode 238 finished.
# Episode 239 finished.
# Episode 240 finished.
# Episode 240	Average Score: 9.10
# Episode 241 finished.
# Episode 242 finished.
# Episode 243 finished.
# Episode 244 finished.
# Episode 245 finished.
# Episode 246 finished.
# Episode 247 finished.
# Episode 248 finished.
# Episode 249 finished.
# Episode 250 finished.
# Episode 250	Average Score: 7.70
# Episode 251 finished.
# Episode 252 finished.
# Episode 253 finished.
# Episode 254 finished.
# Episode 255 finished.
# Episode 256 finished.
# Episode 257 finished.
# Episode 258 finished.
# Episode 259 finished.
# Episode 260 finished.
# Episode 260	Average Score: 7.50
# Episode 261 finished.
# Episode 262 finished.
# Episode 263 finished.
# Episode 264 finished.
# Episode 265 finished.
# Episode 266 finished.
# Episode 267 finished.
# Episode 268 finished.
# Episode 269 finished.
# Episode 270 finished.
# Episode 270	Average Score: 7.90
# Episode 271 finished.
# Episode 272 finished.
# Episode 273 finished.
# Episode 274 finished.
# Episode 275 finished.
# Episode 276 finished.
# Episode 277 finished.
# Episode 278 finished.
# Episode 279 finished.
# Episode 280 finished.
# Episode 280	Average Score: 8.60
# Episode 281 finished.
# Episode 282 finished.
# Episode 283 finished.
# Episode 284 finished.
# Episode 285 finished.
# Episode 286 finished.
# Episode 287 finished.
# Episode 288 finished.
# Episode 289 finished.
# Episode 290 finished.
# Episode 290	Average Score: 6.10
# Episode 291 finished.
# Episode 292 finished.
# Episode 293 finished.
# Episode 294 finished.
# Episode 295 finished.
# Episode 296 finished.
# Episode 297 finished.
# Episode 298 finished.
# Episode 299 finished.
# Episode 300 finished.
# Episode 300	Average Score: 7.80
# Episode 301 finished.
# Episode 302 finished.
# Episode 303 finished.
# Episode 304 finished.
# Episode 305 finished.
# Episode 306 finished.
# Episode 307 finished.
# Episode 308 finished.
# Episode 309 finished.
# Episode 310 finished.
# Episode 310	Average Score: 6.30
# Episode 311 finished.
# Episode 312 finished.
# Episode 313 finished.
# Episode 314 finished.
# Episode 315 finished.
# Episode 316 finished.
# Episode 317 finished.
# Episode 318 finished.
# Episode 319 finished.
# Episode 320 finished.
# Episode 320	Average Score: 9.20
# Episode 321 finished.
# Episode 322 finished.
# Episode 323 finished.
# Episode 324 finished.
# Episode 325 finished.
# Episode 326 finished.
# Episode 327 finished.
# Episode 328 finished.
# Episode 329 finished.
# Episode 330 finished.
# Episode 330	Average Score: 8.40
# Episode 331 finished.
# Episode 332 finished.
# Episode 333 finished.
# Episode 334 finished.
# Episode 335 finished.
# Episode 336 finished.
# Episode 337 finished.
# Episode 338 finished.
# Episode 339 finished.
# Episode 340 finished.
# Episode 340	Average Score: 6.60
# Episode 341 finished.
# Episode 342 finished.
# Episode 343 finished.
# Episode 344 finished.
# Episode 345 finished.
# Episode 346 finished.
# Episode 347 finished.
# Episode 348 finished.
# Episode 349 finished.
# Episode 350 finished.
# Episode 350	Average Score: 8.40
# Episode 351 finished.
# Episode 352 finished.
# Episode 353 finished.
# Episode 354 finished.
# Episode 355 finished.
# Episode 356 finished.
# Episode 357 finished.
# Episode 358 finished.
# Episode 359 finished.
# Episode 360 finished.
# Episode 360	Average Score: 8.10
# Episode 361 finished.
# Episode 362 finished.
# Episode 363 finished.
# Episode 364 finished.
# Episode 365 finished.
# Episode 366 finished.
# Episode 367 finished.
# Episode 368 finished.
# Episode 369 finished.
# Episode 370 finished.
# Episode 370	Average Score: 8.90
# Episode 371 finished.
# Episode 372 finished.
# Episode 373 finished.
# Episode 374 finished.
# Episode 375 finished.
# Episode 376 finished.
# Episode 377 finished.
# Episode 378 finished.
# Episode 379 finished.
# Episode 380 finished.
# Episode 380	Average Score: 6.90
# Episode 381 finished.
# Episode 382 finished.
# Episode 383 finished.
# Episode 384 finished.
# Episode 385 finished.
# Episode 386 finished.
# Episode 387 finished.
# Episode 388 finished.
# Episode 389 finished.
# Episode 390 finished.
# Episode 390	Average Score: 8.50
# Episode 391 finished.
# Episode 392 finished.
# Episode 393 finished.
# Episode 394 finished.
# Episode 395 finished.
# Episode 396 finished.
# Episode 397 finished.
# Episode 398 finished.
# Episode 399 finished.
# Episode 400 finished.
# Episode 400	Average Score: 8.00
# Episode 401 finished.
# Episode 402 finished.
# Episode 403 finished.
# Episode 404 finished.
# Episode 405 finished.
# Episode 406 finished.
# Episode 407 finished.
# Episode 408 finished.
# Episode 409 finished.
# Episode 410 finished.
# Episode 410	Average Score: 8.80
# Episode 411 finished.
# Episode 412 finished.
# Episode 413 finished.
# Episode 414 finished.
# Episode 415 finished.
# Episode 416 finished.
# Episode 417 finished.
# Episode 418 finished.
# Episode 419 finished.
# Episode 420 finished.
# Episode 420	Average Score: 7.00
# Episode 421 finished.
# Episode 422 finished.
# Episode 423 finished.
# Episode 424 finished.
# Episode 425 finished.
# Episode 426 finished.
# Episode 427 finished.
# Episode 428 finished.
# Episode 429 finished.
# Episode 430 finished.
# Episode 430	Average Score: 7.60
# Episode 431 finished.
# Episode 432 finished.
# Episode 433 finished.
# Episode 434 finished.
# Episode 435 finished.
# Episode 436 finished.
# Episode 437 finished.
# Episode 438 finished.
# Episode 439 finished.
# Episode 440 finished.
# Episode 440	Average Score: 7.70
# Episode 441 finished.
# Episode 442 finished.
# Episode 443 finished.
# Episode 444 finished.
# Episode 445 finished.
# Episode 446 finished.
# Episode 447 finished.
# Episode 448 finished.
# Episode 449 finished.
# Episode 450 finished.
# Episode 450	Average Score: 8.70
# Episode 451 finished.
# Episode 452 finished.
# Episode 453 finished.
# Episode 454 finished.
# Episode 455 finished.
# Episode 456 finished.
# Episode 457 finished.
# Episode 458 finished.
# Episode 459 finished.
# Episode 460 finished.
# Episode 460	Average Score: 6.80
# Episode 461 finished.
# Episode 462 finished.
# Episode 463 finished.
# Episode 464 finished.
# Episode 465 finished.
# Episode 466 finished.
# Episode 467 finished.
# Episode 468 finished.
# Episode 469 finished.
# Episode 470 finished.
# Episode 470	Average Score: 6.90
# Episode 471 finished.
# Episode 472 finished.
# Episode 473 finished.
# Episode 474 finished.
# Episode 475 finished.
# Episode 476 finished.
# Episode 477 finished.
# Episode 478 finished.
# Episode 479 finished.
# Episode 480 finished.
# Episode 480	Average Score: 8.00
# Episode 481 finished.
# Episode 482 finished.
# Episode 483 finished.
# Episode 484 finished.
# Episode 485 finished.
# Episode 486 finished.
# Episode 487 finished.
# Episode 488 finished.
# Episode 489 finished.
# Episode 490 finished.
# Episode 490	Average Score: 7.60
# Episode 491 finished.
# Episode 492 finished.
# Episode 493 finished.
# Episode 494 finished.
# Episode 495 finished.
# Episode 496 finished.
# Episode 497 finished.
# Episode 498 finished.
# Episode 499 finished.
# Episode 500 finished.
# Episode 500	Average Score: 7.40
# Episode 501 finished.
# Episode 502 finished.
# Episode 503 finished.
# Episode 504 finished.
# Episode 505 finished.
# Episode 506 finished.
# Episode 507 finished.
# Episode 508 finished.
# Episode 509 finished.
# Episode 510 finished.
# Episode 510	Average Score: 7.10
# Episode 511 finished.
# Episode 512 finished.
# Episode 513 finished.
# Episode 514 finished.
# Episode 515 finished.
# Episode 516 finished.
# Episode 517 finished.
# Episode 518 finished.
# Episode 519 finished.
# Episode 520 finished.
# Episode 520	Average Score: 7.60
# Episode 521 finished.
# Episode 522 finished.
# Episode 523 finished.
# Episode 524 finished.
# Episode 525 finished.
# Episode 526 finished.
# Episode 527 finished.
# Episode 528 finished.
# Episode 529 finished.
# Episode 530 finished.
# Episode 530	Average Score: 7.50
# Episode 531 finished.
# Episode 532 finished.
# Episode 533 finished.
# Episode 534 finished.
# Episode 535 finished.
# Episode 536 finished.
# Episode 537 finished.
# Episode 538 finished.
# Episode 539 finished.
# Episode 540 finished.
# Episode 540	Average Score: 9.10
# Episode 541 finished.
# Episode 542 finished.
# Episode 543 finished.
# Episode 544 finished.
# Episode 545 finished.
# Episode 546 finished.
# Episode 547 finished.
# Episode 548 finished.
# Episode 549 finished.
# Episode 550 finished.
# Episode 550	Average Score: 6.70
# Episode 551 finished.
# Episode 552 finished.
# Episode 553 finished.
# Episode 554 finished.
# Episode 555 finished.
# Episode 556 finished.
# Episode 557 finished.
# Episode 558 finished.
# Episode 559 finished.
# Episode 560 finished.
# Episode 560	Average Score: 6.90
# Episode 561 finished.
# Episode 562 finished.
# Episode 563 finished.
# Episode 564 finished.
# Episode 565 finished.
# Episode 566 finished.
# Episode 567 finished.
# Episode 568 finished.
# Episode 569 finished.
# Episode 570 finished.
# Episode 570	Average Score: 8.30
# Episode 571 finished.
# Episode 572 finished.
# Episode 573 finished.
# Episode 574 finished.
# Episode 575 finished.
# Episode 576 finished.
# Episode 577 finished.
# Episode 578 finished.
# Episode 579 finished.
# Episode 580 finished.
# Episode 580	Average Score: 7.60
# Episode 581 finished.
# Episode 582 finished.
# Episode 583 finished.
# Episode 584 finished.
# Episode 585 finished.
# Episode 586 finished.
# Episode 587 finished.
# Episode 588 finished.
# Episode 589 finished.
# Episode 590 finished.
# Episode 590	Average Score: 8.40
# Episode 591 finished.
# Episode 592 finished.
# Episode 593 finished.
# Episode 594 finished.
# Episode 595 finished.
# Episode 596 finished.
# Episode 597 finished.
# Episode 598 finished.
# Episode 599 finished.
# Episode 600 finished.
# Episode 600	Average Score: 7.70
# Episode 601 finished.
# Episode 602 finished.
# Episode 603 finished.
# Episode 604 finished.
# Episode 605 finished.
# Episode 606 finished.
# Episode 607 finished.
# Episode 608 finished.
# Episode 609 finished.
# Episode 610 finished.
# Episode 610	Average Score: 8.30
# Episode 611 finished.
# Episode 612 finished.
# Episode 613 finished.
# Episode 614 finished.
# Episode 615 finished.
# Episode 616 finished.
# Episode 617 finished.
# Episode 618 finished.
# Episode 619 finished.
# Episode 620 finished.
# Episode 620	Average Score: 8.60
# Episode 621 finished.
# Episode 622 finished.
# Episode 623 finished.
# Episode 624 finished.
# Episode 625 finished.
# Episode 626 finished.
# Episode 627 finished.
# Episode 628 finished.
# Episode 629 finished.
# Episode 630 finished.
# Episode 630	Average Score: 6.70
# Episode 631 finished.
# Episode 632 finished.
# Episode 633 finished.
# Episode 634 finished.
# Episode 635 finished.
# Episode 636 finished.
# Episode 637 finished.
# Episode 638 finished.
# Episode 639 finished.
# Episode 640 finished.
# Episode 640	Average Score: 6.50
# Episode 641 finished.
# Episode 642 finished.
# Episode 643 finished.
# Episode 644 finished.
# Episode 645 finished.
# Episode 646 finished.
# Episode 647 finished.
# Episode 648 finished.
# Episode 649 finished.
# Episode 650 finished.
# Episode 650	Average Score: 8.90
# Episode 651 finished.
# Episode 652 finished.
# Episode 653 finished.
# Episode 654 finished.
# Episode 655 finished.
# Episode 656 finished.
# Episode 657 finished.
# Episode 658 finished.
# Episode 659 finished.
# Episode 660 finished.
# Episode 660	Average Score: 9.20
# Episode 661 finished.
# Episode 662 finished.
# Episode 663 finished.
# Episode 664 finished.
# Episode 665 finished.
# Episode 666 finished.
# Episode 667 finished.
# Episode 668 finished.
# Episode 669 finished.
# Episode 670 finished.
# Episode 670	Average Score: 8.20
# Episode 671 finished.
# Episode 672 finished.
# Episode 673 finished.
# Episode 674 finished.
# Episode 675 finished.
# Episode 676 finished.
# Episode 677 finished.
# Episode 678 finished.
# Episode 679 finished.
# Episode 680 finished.
# Episode 680	Average Score: 8.60
# Episode 681 finished.
# Episode 682 finished.
# Episode 683 finished.
# Episode 684 finished.
# Episode 685 finished.
# Episode 686 finished.
# Episode 687 finished.
# Episode 688 finished.
# Episode 689 finished.
# Episode 690 finished.
# Episode 690	Average Score: 8.30
# Episode 691 finished.
# Episode 692 finished.
# Episode 693 finished.
# Episode 694 finished.
# Episode 695 finished.
# Episode 696 finished.
# Episode 697 finished.
# Episode 698 finished.
# Episode 699 finished.
# Episode 700 finished.
# Episode 700	Average Score: 7.40
# Episode 701 finished.
# Episode 702 finished.
# Episode 703 finished.
# Episode 704 finished.
# Episode 705 finished.
# Episode 706 finished.
# Episode 707 finished.
# Episode 708 finished.
# Episode 709 finished.
# Episode 710 finished.
# Episode 710	Average Score: 8.40
# Episode 711 finished.
# Episode 712 finished.
# Episode 713 finished.
# Episode 714 finished.
# Episode 715 finished.
# Episode 716 finished.
# Episode 717 finished.
# Episode 718 finished.
# Episode 719 finished.
# Episode 720 finished.
# Episode 720	Average Score: 7.70
# Episode 721 finished.
# Episode 722 finished.
# Episode 723 finished.
# Episode 724 finished.
# Episode 725 finished.
# Episode 726 finished.
# Episode 727 finished.
# Episode 728 finished.
# Episode 729 finished.
# Episode 730 finished.
# Episode 730	Average Score: 9.20
# Episode 731 finished.
# Episode 732 finished.
# Episode 733 finished.
# Episode 734 finished.
# Episode 735 finished.
# Episode 736 finished.
# Episode 737 finished.
# Episode 738 finished.
# Episode 739 finished.
# Episode 740 finished.
# Episode 740	Average Score: 7.90
# Episode 741 finished.
# Episode 742 finished.
# Episode 743 finished.
# Episode 744 finished.
# Episode 745 finished.
# Episode 746 finished.
# Episode 747 finished.
# Episode 748 finished.
# Episode 749 finished.
# Episode 750 finished.
# Episode 750	Average Score: 5.60
# Episode 751 finished.
# Episode 752 finished.
# Episode 753 finished.
# Episode 754 finished.
# Episode 755 finished.
# Episode 756 finished.
# Episode 757 finished.
# Episode 758 finished.
# Episode 759 finished.
# Episode 760 finished.
# Episode 760	Average Score: 7.30
# Episode 761 finished.
# Episode 762 finished.
# Episode 763 finished.
# Episode 764 finished.
# Episode 765 finished.
# Episode 766 finished.
# Episode 767 finished.
# Episode 768 finished.
# Episode 769 finished.
# Episode 770 finished.
# Episode 770	Average Score: 6.60
# Episode 771 finished.
# Episode 772 finished.
# Episode 773 finished.
# Episode 774 finished.
# Episode 775 finished.
# Episode 776 finished.
# Episode 777 finished.
# Episode 778 finished.
# Episode 779 finished.
# Episode 780 finished.
# Episode 780	Average Score: 7.50
# Episode 781 finished.
# Episode 782 finished.
# Episode 783 finished.
# Episode 784 finished.
# Episode 785 finished.
# Episode 786 finished.
# Episode 787 finished.
# Episode 788 finished.
# Episode 789 finished.
# Episode 790 finished.
# Episode 790	Average Score: 6.50
# Episode 791 finished.
# Episode 792 finished.
# Episode 793 finished.
# Episode 794 finished.
# Episode 795 finished.
# Episode 796 finished.
# Episode 797 finished.
# Episode 798 finished.
# Episode 799 finished.
# Episode 800 finished.
# Episode 800	Average Score: 7.10
# Episode 801 finished.
# Episode 802 finished.
# Episode 803 finished.
# Episode 804 finished.
# Episode 805 finished.
# Episode 806 finished.
# Episode 807 finished.
# Episode 808 finished.
# Episode 809 finished.
# Episode 810 finished.
# Episode 810	Average Score: 9.90
# Environment solved in 810 episodes!
# Total duration: 464.02 seconds
# Average time for training: 0.49 seconds
# Average time for updating: 0.04 seconds
# Average time for synchronizing: 0.04 seconds

# %%
import matplotlib.pyplot as plt
import json

filename = "taxi_data.json"

data = []
with open(filename, 'r') as f:
    data = json.load(f)


variables = ['gamma', 'learning_rate']
filter_dict = {
    "num_agents": 4,
    "num_epochs_actor_train": 10,
    "batch_size": 64,
    "gamma": 0.99,
    "tau": 1e-3,
    "learning_rate": 1e-3,
    "update_every": 4,
    "max_time_steps": 1000,
    "num_episodes": 2000,
    "cutoff_score": 9.7,
    "consecutive_cutoff": 5,
    "consecutive_count": 0
}

for v in variables:
    del filter_dict[v]

results = []

for d in data:
    hyperparam = d['parameters']
    run = d['training']
    is_match = True
    for key, val in filter_dict.items():
        if val != hyperparam[key]:
            is_match = False
            break
    
    if is_match:
        results.append(([(v, hyperparam[v]) for v in variables], run))

print(len(results))

fig = plt.figure()

for param, r in results:
    game_data = list(zip(*r))
    plt.plot(list(game_data[0]), list(game_data[2]), marker='o', label=str(param))

plt.xlabel("Time (s)")
plt.ylabel("Average Game Score")
plt.ylim((-200, 15))

plt.title(f"Taxi: Hyperparameter Tuning - {str(variables)}")
plt.tight_layout()
plt.legend(title=str(variables))
plt.savefig(f"taxi_tuning_{str(variables)}.png", dpi=300)
# Out:
# 7

# %%
import matplotlib.pyplot as plt

game_data = list(zip(*game_score_times))
plt.plot(list(game_data[0]), list(game_data[2]), marker='o')
plt.xlabel("Time (s)")
plt.ylabel("Average Game Score")
plt.ylim((-200, 15))

plt.title(f"batch_size = {batch_size} | num_epochs_actor_train = {num_epochs_actor_train} | num_agents = {num_agents}")
plt.tight_layout()
plt.savefig(f"{batch_size}_{num_epochs_actor_train}_{num_agents}_{len(data)}.png", dpi=300)

# %%
import matplotlib.pyplot as plt

game_data = list(zip(*game_score_times))
plt.plot(list(game_data[0]), list(game_data[2]), marker='o')
plt.xlabel("Time (s)")
plt.ylabel("Average Game Score")
plt.ylim((0, 15))
plt.xlim((700, 900))

plt.title(f"batch_size = {batch_size} | num_epochs_actor_train = {num_epochs_actor_train} | num_agents = {num_agents}")
plt.tight_layout()
plt.savefig(f"{batch_size}_{num_epochs_actor_train}_{num_agents}_{len(data)}_detailed.png", dpi=300)

# %%
ray.shutdown()

# %% [markdown]
# # Visualize the game playing just for fun

# %% [markdown]
# The code snippets below are fully implemented and are optional.
# It provides a way for you to visualize how your trained model plays Lunar Lander.

# %%
import random
import numpy as np
import torch
import gym
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from collections import deque, namedtuple
import time
import socket
from pyvirtualdisplay import Display
virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
'''
Duplicate classes needed for testing
'''
class QNetwork(nn.Module):
    def __init__(self, state_size, action_size, seed, fc1_unit=64,
                 fc2_unit=64):
        """
        Initialize parameters and build model.
        Params
        =======
            state_size (int): Dimension of each state
            action_size (int): Dimension of each action
            seed (int): Random seed
            fc1_unit (int): Number of nodes in first hidden layer
            fc2_unit (int): Number of nodes in second hidden layer
        """
        super(QNetwork, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, fc1_unit)
        self.fc2 = nn.Linear(fc1_unit, fc2_unit)
        self.fc3 = nn.Linear(fc2_unit, action_size)

    def forward(self, x):
        """
        Build a network that maps state -> action values.
        """
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

class ReplayBuffer:
    """Fixed-size buffer to store experience tuples."""
    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayBuffer object.
        Params
        ======
            action_size (int): dimension of each action
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
            seed (int): random seed
        """
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        random.seed(seed)

    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)

    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float()
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long()
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float()
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float()
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float()

        return states, actions, rewards, next_states, dones

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

        
'''
The Agent is interacting with the environment to learn an optimal policy for decision-making.
'''
class Agent:
    """Interacts with and learns from the environment."""

    def __init__(self, state_size, action_size, seed):
        """Initialize an Agent object.

        Params
        ======
            state_size (int): dimension of each state
            action_size (int): dimension of each action
            seed (int): random seed
        """
        random.seed(seed)
        self.state_size = state_size
        self.action_size = action_size

        # Q-Network
        self.qnetwork_local = QNetwork(state_size, action_size, seed)
        self.qnetwork_target = QNetwork(state_size, action_size, seed)
        self.optimizer = optim.Adam(self.qnetwork_local.parameters(), lr=LR)

        # Replay memory
        self.memory = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, seed)

        # Initialize time step (for updating every UPDATE_EVERY steps)
        self.t_step = 0

    def step(self, state, action, reward, next_state, done):
        # Save experience in replay memory
        self.memory.add(state, action, reward, next_state, done)

        # Learn every UPDATE_EVERY time steps.
        self.t_step = (self.t_step + 1) % UPDATE_EVERY
        if self.t_step == 0:
            # If enough samples are available in memory, get random subset and learn
            if len(self.memory) > BATCH_SIZE:
                experiences = self.memory.sample()
                self.learn(experiences, GAMMA)

    def act(self, state, eps=0.):
        """Returns actions for given state as per current policy.

        Params
        ======
            state (array_like): current state
            eps (float): epsilon, for epsilon-greedy action selection
        """
        state = torch.from_numpy(state).float().unsqueeze(0)
        self.qnetwork_local.eval()
        with torch.no_grad():
            action_values = self.qnetwork_local(state)
        self.qnetwork_local.train()

        # Epsilon-greedy action selection
        if random.random() > eps:
            return np.argmax(action_values.cpu().data.numpy())
        else:
            return random.choice(np.arange(self.action_size))

    def learn(self, experiences, gamma):
        """Update value parameters using given batch of experience tuples.
        Params
        ======
            experiences (Tuple[torch.Tensor]): tuple of (s, a, r, s', done) tuples
            gamma (float): discount factor
        """
        states, actions, rewards, next_states, dones = experiences

        # Get max predicted Q values (for next states) from target model
        q_targets_next = self.qnetwork_target(next_states).detach().max(1)[0].unsqueeze(1)
        # Compute Q targets for current states
        q_targets = rewards + (gamma * q_targets_next * (1 - dones))

        # Get expected Q values from local model
        q_expected = self.qnetwork_local(states).gather(1, actions)

        # Compute loss
        loss = F.mse_loss(q_expected, q_targets)
        # Minimize the loss
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # update target network
        self.soft_update(self.qnetwork_local, self.qnetwork_target, TAU)

    def soft_update(self, local_model, target_model, tau):
        """Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target
        Params
        ======
            local_model (PyTorch model): weights will be copied from
            target_model (PyTorch model): weights will be copied to
            tau (float): interpolation parameter
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau * local_param.data + (1.0 - tau) * target_param.data)

# %% [raw]
# from matplotlib.figure import Figure
# from io import BytesIO
# def text_to_rgba(s, dpi=300, **kwargs):
#     # To convert a text string to an image, we can:
#     # - draw it on an empty and transparent figure;
#     # - save the figure to a temporary buffer using ``bbox_inches="tight",
#     #   pad_inches=0`` which will pick the correct area to save;
#     # - load the buffer using ``plt.imread``.
#     #
#     # (If desired, one can also directly save the image to the filesystem.)
#     fig = Figure(facecolor="none")
#     fig.text(0, 0, s, **kwargs)
#     with BytesIO() as buf:
#         fig.savefig(buf, dpi=dpi, format="png", bbox_inches="tight",
#                     pad_inches=0)
#         buf.seek(0)
#         rgba = plt.imread(buf)
#     return rgba
#
#
# def display_animation(frames):
#     """
#     Take a list of frames and display them as an animation.
#     """
#     plt.figure(figsize=(5, 3))
#     plt.axis('off')
#     patch = plt.imshow(text_to_rgba(frames[0], 300))
#
#     def animate(i):
#         #clear_output(wait=True)
#         #print(frames[i])
#         #print(f"Timestep: {i + 1}")
#         patch.set_data(text_to_rgba(frames[i], 300))
#
#     anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)
#     display(HTML(anim.to_jshtml()))
#
#
# def display_animation(frames):
#     """
#     Take a list of frames and display them as an animation.
#     """
#     plt.figure(figsize=(5, 3))
#     plt.axis('off')
#
#     def animate(i):
#         clear_output(wait=True)
#         print(frames[i])
#         print(f"Timestep: {i + 1}")
#         #patch.set_data(text_to_rgba(frames[i], 300))
#
#     anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)
#     display(HTML(anim.to_jshtml()))

# %%
'''
Load the previously saved trained model from the last checkpoint 
and do tests to display a visualization of the game being played.
'''
import gym
import torch
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import display, HTML
import random
# set random seed
SEED=0
TEST_SEED=42
random.seed(SEED)

# hyper parameters
BUFFER_SIZE = int(1e5)  # replay buffer size
BATCH_SIZE = 64  # minibatch size
GAMMA = 0.99  # discount factor
TAU = 1e-3  # for soft update of target parameters
LR = 5e-4  # learning rate
UPDATE_EVERY = 4  # how often to update the network
MAX_TIME_STEPS= 1000  # max time steps in an episode
num_episodes = 1000   # how many episodes for training

random.seed(0)
env = gym.make('Taxi-v3')
env.seed(42)
agent = Agent(state_size=500, action_size=6, seed=0)

# TODO: You may need to modify the path accordingly if the default does not match.
model_path='./model_checkpoint.pth'
agent.qnetwork_local.load_state_dict(torch.load(model_path, map_location='cpu'))

# Resources used: https://github.com/take2rohit/taxi_v3_openai/blob/master/Q-Learning_taxi.ipynb
from IPython.display import clear_output, display
from time import sleep
def print_frames(frames):
    for i, frame in enumerate(frames):
        clear_output(wait=True)
        print(frame)
        print(f"Timestep: {i + 1}")
        #print(f"State: {frame['state']}")
        #print(f"Action: {frame['action']}")
        #print(f"Reward: {frame['reward']}")
        sleep(0.5)

# run several episodes and show games
collective_games = []
for i in range(5):
    state = env.reset()
    if not isinstance(state, int):
        state = state[0]
    state, _ = get_one_hot_encoding(state, 0)
    frames = []
    for j in range(1000):    # set max steps to 1000
        action = agent.act(state)
        frames.append(env.render("ansi"))
        state, reward, done, _ = env.step(action)
        if not isinstance(state, int):
            state = state[0]
        state, _ = get_one_hot_encoding(state, 0)
        if done:
            break
    collective_games.append(frames)

for i, c in enumerate(collective_games):
    print(f"STARTING GAME {i+1}")
    sleep(1)
    print_frames(c)
    clear_output()
env.close()
